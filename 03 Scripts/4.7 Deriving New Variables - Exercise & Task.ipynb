# %% [markdown]
# # 4.7 Deriving New Variables
#
# ## Contents list:
#
# ### 01. Importing libraries
# ### 02. Importing data
#
# ## Exercise 4.7; Steps
# ## Task 4.7; Steps
#
# ### 03. Exporting data

# %% [markdown]
# # 0.1 Importing libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Importing data

# %%
# Project folder path as string
path = r'C:\Users\User\Desktop\Instacart Basket Analysis'

# %%
# Import orders_products_merged dataframe using the os library
df_ords_prods_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %% [markdown]
# # Exercise 4.7

# %%
# Create a subset of the df_ords_prods_merged  
df = df_ords_prods_merged[:1000000]

# %%
# Check shape
df.shape
# Out:
# (1000000, 14)

# %%
# Define function
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
# Apply the function
df['price_range'] = df.apply(price_label, axis=1)

# %%
# Check the values in new column
df['price_range'].value_counts(dropna=False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
# Check the most expensive product within the subset
df['prices'].max()
# Out:
# 14.8

# %%
# Running loc() function on entire df_ords_prods_merged
df_ords_prods_merged.loc[df_ords_prods_merged['prices']>15, 'price_range_loc']='High-range product'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['prices'] <= 15) & (df_ords_prods_merged['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
# Check the values in new column
df_ords_prods_merged['price_range_loc'].value_counts(dropna=False)
# Out:
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      417678
# Name: price_range_loc, dtype: int64

# %%
# Frequency of the "orders_day_of_week"
df_ords_prods_merged['orders_day_of_week'].value_counts(dropna=False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_week, dtype: int64

# %%
# For-loop

result = []

for value in df_ords_prods_merged['orders_day_of_week']:
  if value == 0:
    result.append('Busiest day')
  elif value == 4:
    result.append('Least busy')
  else:
    result.append('Regularly busy')

# %%
# Result list
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
# Create a new column
df_ords_prods_merged['busiest_day']=result

# %%
# Frequency of the "busiest_day"
df_ords_prods_merged['busiest_day'].value_counts(dropna=False)
# Out:
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: busiest_day, dtype: int64

# %%
# Check frequency of the "orders_day_of_week" & "busiest_day"

print (df_ords_prods_merged[['orders_day_of_week', 'busiest_day']].value_counts(dropna=False))
# Out:
# orders_day_of_week  busiest_day
# 0                   Busiest day       6204182
# 1                   Regularly busy    5660230
# 6                   Regularly busy    4496490
# 2                   Regularly busy    4213830
# 5                   Regularly busy    4205791
# 3                   Regularly busy    3840534
# 4                   Least busy        3783802
# dtype: int64

# %% [markdown]
# # Task 4.7

# %% [markdown]
#  Step 1 - Exercise 4.7

# %%
# Step 2 - Frequency of the "orders_day_of_week"
df_ords_prods_merged['orders_day_of_week'].value_counts(dropna=False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_week, dtype: int64

# %%
# For-loop
result_value = []

for value in df_ords_prods_merged['orders_day_of_week']:
  if value == 0 or value == 1:
    result_value.append('Busiest days')
  elif value == 4 or value == 3:
    result_value.append('Slowest days')
  else:
    result_value.append('Regulary busy days')

# %%
# Result_value list
result_value
# Out:
# ['Regulary busy days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Regulary busy days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
#  'Busiest days',
#  'Regulary busy days',
#  'Regulary busy days',
#  'Busiest days',
#  'Busiest days',
#  'Regulary busy days',
#  'Regulary busy days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Regulary busy days',
#  'Regulary busy days',
#  'Busiest days',
#  'Regulary busy days',
#  'Regulary busy days',
#  'Busiest days',
#  'Regulary busy days',
#  'Regulary busy days',
#  'Regulary busy days',
#  'Slowest days',
#  'Regulary busy days',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Regulary busy days',
#  'Slowest days',
#  'Slowest days',
#  'Regulary busy days',
#  'Regulary busy days',
#  'Busiest days',
#  'Busiest days',
# ...

# %%
# Create a new column
df_ords_prods_merged['Busiest_days']=result_value

# %%
# Frequency of the "busiest_days"
df_ords_prods_merged['Busiest_days'].value_counts(dropna=False)
# Out:
# Regulary busy days    12916111
# Busiest days          11864412
# Slowest days           7624336
# Name: Busiest_days, dtype: int64

# %%
# Step 3 - Check the values of "Busiest_days" column for accuracy
print(df_ords_prods_merged[['orders_day_of_week', 'Busiest_days']]. head(30))
# Out:
#     orders_day_of_week        Busiest_days
# 0                    2  Regulary busy days
# 1                    3        Slowest days
# 2                    3        Slowest days
# 3                    4        Slowest days
# 4                    4        Slowest days
# 5                    2  Regulary busy days
# 6                    1        Busiest days
# 7                    1        Busiest days
# 8                    1        Busiest days
# 9                    4        Slowest days
# 10                   1        Busiest days
# 11                   2  Regulary busy days
# 12                   2  Regulary busy days
# 13                   1        Busiest days
# 14                   1        Busiest days
# 15                   5  Regulary busy days
# 16                   6  Regulary busy days
# 17                   4        Slowest days
# 18                   3        Slowest days
# 19                   3        Slowest days
# 20                   3        Slowest days
# ...

# %%
# Step 4 - The busiest hours of day
df_ords_prods_merged['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: order_hour_of_day, dtype: int64

# %% [markdown]
#  1 day = 24 h
#
#  24h \3 time periods = 8 h\time period
#
#  "Most orders" = 10, 11, 14, 15, 13, 12, 16, 9 --- (9-16)
#
#  "Average orders" = 17, 8, 18, 19, 20, 7, 21, 22 --- (7-8 and 17-22)
#
#  "Fewest orders" = 23, 6, 0, 1, 5, 2, 4, 3 --- (23-6)

# %%
# For-loop 

result_value2 = []

for value2 in df_ords_prods_merged['order_hour_of_day']:
  if value2 in [10,11,14,15,13,12,16,9]:
    result_value2.append('Most orders')
  elif value2 in[23,6,0,1,5,2,4,3]:
    result_value2.append('Fewst orders')
  else:
    result_value2.append('Average orders')

# %%
# Result_value2 list
result_value2
# Out:
# ['Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
# ...

# %%
# Create new column "busiest_period_of_day"
df_ords_prods_merged['busiest_period_of_day']=result_value2

# %%
# Step 5 - Frequency of the "busiest_period_of_day"
df_ords_prods_merged['busiest_period_of_day'].value_counts(dropna=False)
# Out:
# Most orders       21118071
# Average orders     9997651
# Fewst orders       1289137
# Name: busiest_period_of_day, dtype: int64

# %% [markdown]
# ### 03. Exporting data

# %%
# Step 7 - Exporting the df_ords_prods_merged in pickle format as 'orders_products_merged_new_columns_added.pkl'
df_ords_prods_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged_new_columns_added.pkl'))
